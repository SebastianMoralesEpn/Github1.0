# %% [markdown]
# # Escuela Politecnica Nacional
# ## Taller 01
# **Nombre:** Sebastián Morales
#
# **Fecha:** 28/04/2025

# %% [markdown]
# # Algoritmo 03

# %% [markdown]
# ![Algoritmo03.png](attachment:Algoritmo03.png)
