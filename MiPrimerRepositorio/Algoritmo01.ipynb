# %% [markdown]
# # Escuela Politecnica Nacional
# ## Taller 01
# **Nombre:** Sebastián Morales
#
# **Fecha:** 28/04/2025

# %% [markdown]
# ## Algoritmo 01

# %% [markdown]
# ![Algoritmo01.png](attachment:Algoritmo01.png)

# %%
def algoritmo01(N, X):
    SUM = 0  
    for i in range(N):  
        SUM += X[i] 
    return SUM  

# Casos de prueba
X1 = list(range(100))  # Primer caso de prueba
resultado1 = algoritmo01(len(X1), X1)
print("Caso 1:", resultado1)

X2 = [1, 1/2, 1/4]  # Segundo caso de prueba
resultado2 = algoritmo01(len(X2), X2)
print("Caso 2:", resultado2)

# Generación de la lista X
X = [1 / 2**x for x in range(15)]
print("Lista X:", X)

# Aplicación del algoritmo
r = algoritmo01(len(X), X)
print("Resultado r:", r)

# Cálculo de la diferencia con 2
diferencia = 2 - r
print(f"Diferencia 2 - r: {diferencia}")
# Out:
# Caso 1: 4950
# Caso 2: 1.75
# Lista X: [1.0, 0.5, 0.25, 0.125, 0.0625, 0.03125, 0.015625, 0.0078125, 0.00390625, 0.001953125, 0.0009765625, 0.00048828125, 0.000244140625, 0.0001220703125, 6.103515625e-05]
# Resultado r: 1.99993896484375
# Diferencia 2 - r: 6.103515625e-05

# %% [markdown]
# ![Quizz-Algoritmo01.png](attachment:Quizz-Algoritmo01.png)

# %%
# Ejerccicio del Quizz (Calcular la suma hasta que el error absoluto sea menor a 10^-1)
def algoritmo01(N, X):
    SUM = 0  
    for i in range(N):  
        SUM += X[i]  
        if 2 - SUM < 10**-1:  # Condición de error absoluto
            return SUM, i + 1  # Retorna la suma y el número de elementos usados
    return SUM, N  

# Generación de la lista X 
X = [1 / 2**x for x in range(100)]  # Se genera un número grande de términos por precaución

# Aplicación del algoritmo
r, min_elementos = algoritmo01(len(X), X)

print("Resultado r:", r)
print("Número mínimo de elementos:", min_elementos)
print(f"Diferencia 2 - r: {2 - r}")
# Out:
# Resultado r: 1.9375
# Número mínimo de elementos: 5
# Diferencia 2 - r: 0.0625
