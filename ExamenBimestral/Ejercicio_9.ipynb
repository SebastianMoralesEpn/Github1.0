# %% [markdown]
# **Examen Bimestral**
#
# **Nombre:** Sebastian Morales
#
# **Fecha:** 12/06/2025

# %%
import numpy as np
import matplotlib.pyplot as plt

# Datos originales
x = [4.1,3.6,3.3,0.2,9.8,9.5,3.2,5.8,0.7,4.2,5.4,6.3,0.3,1.0,9.3,2.4,4.7,8.8,5.2,5.6,4.8,9.7,7.5,0.7,8.2,0.6,2.3,8.4,0.4,1.6,1.5,9.6,6.6,0.9,8.2,5.5,9.4,4.3,6.4,3.3,2.8,3.3,0.9,5.8,4.3,1.0,5.4,8.0,8.6,4.0,8.9,3.0,9.2,3.3,8.9,2.3,1.9,3.5,4.3,5.8,8.9,0.7,5.8,6.2,2.4,1.5,0.2,3.1,6.2,4.5,3.1,1.3,2.0,-200.0,0.4,5.4,4.6,0.6,1.6,1.9,2.2,6.4,1.1,7.9,8.1,3.8,1.1,3.0,5.6,5.4,0.3,8.3,8.5,5.3,1.5,0.9,2.7,3.0,8.0,2.0,9.4]
y = [5.4,5.4,5.3,5.0,6.1,6.0,5.3,5.5,5.2,5.4,5.7,5.7,5.1,5.3,5.7,5.2,5.5,6.0,5.5,5.7,5.5,6.1,5.9,5.1,5.9,5.0,5.3,5.6,5.1,5.1,5.1,6.0,5.5,5.0,6.1,5.5,5.9,5.4,5.6,5.5,5.3,5.2,5.3,5.7,5.5,5.1,5.5,5.9,5.8,5.4,5.8,5.4,5.9,5.3,5.9,5.1,5.1,5.5,5.4,5.5,5.9,5.1,5.6,5.7,5.3,5.1,5.1,5.3,5.6,5.4,5.3,5.1,5.3,500,5.1,5.5,5.6,4.9,5.2,5.2,5.4,5.5,5.0,5.8,5.6,5.3,4.9,5.4,5.6,5.5,5.1,6.1,5.8,5.6,5.1,5.1,5.3,5.3,5.7,5.2,6.0]

# Filtrar valores atípicos
x_filtrado = []
y_filtrado = []
for xi, yi in zip(x, y):
    if -100 < xi < 100 and yi < 100:
        x_filtrado.append(xi)
        y_filtrado.append(yi)

# Ajuste lineal
coef = np.polyfit(x_filtrado, y_filtrado, 1)
polinomio = np.poly1d(coef)

# Graficar
plt.scatter(x_filtrado, y_filtrado, label='Datos filtrados')
plt.plot(sorted(x_filtrado), polinomio(sorted(x_filtrado)), color='red', label='Ajuste lineal')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gráfica de dispersión y ajuste lineal')
plt.grid(True)
plt.legend()
plt.show()

# ...código anterior de filtrado...

# Polinomio interpolador de grado n-1
grado = len(x_filtrado) - 1
coef_interp = np.polyfit(x_filtrado, y_filtrado, grado)
polinomio_interp = np.poly1d(coef_interp)

print("Polinomio interpolador:")
print(polinomio_interp)
# Out:
# Polinomio interpolador:
#            99            98             97             96
# 3.033e-88 x  - 2.01e-87 x  - 2.767e-86 x  - 1.641e-85 x
#               95             94             93             92
#  - 7.215e-86 x  + 1.185e-83 x  + 1.835e-82 x  + 1.867e-81 x
#               91             90             89            88
#  + 1.423e-80 x  + 7.074e-80 x  - 7.532e-80 x  - 7.58e-78 x
#               87             86             85             84
#  - 1.228e-76 x  - 1.433e-75 x  - 1.374e-74 x  - 1.092e-73 x
#               83             82             81             80
#  - 6.582e-73 x  - 1.559e-72 x  + 3.328e-71 x  + 7.379e-70 x
#               79             78             77             76
#  + 1.008e-68 x  + 1.117e-67 x  + 1.062e-66 x  + 8.633e-66 x
#               75            74             73             72
#  + 5.578e-65 x  + 1.94e-64 x  - 1.752e-63 x  - 5.004e-62 x
#               71            70             69             68
#  - 7.405e-61 x  - 8.68e-60 x  - 8.716e-59 x  - 7.569e-58 x
#               67             66             65             64
#  - 5.451e-57 x  - 2.692e-56 x  + 3.056e-56 x  + 3.119e-54 x
#               63             62             61             60
#  + 5.364e-53 x  + 6.746e-52 x  + 7.097e-51 x  + 6.399e-50 x
#               59             58            57             56
#  + 4.788e-49 x  + 2.528e-48 x  - 2.13e-49 x  - 2.459e-46 x
#               55             54             53             52
#  - 4.405e-45 x  - 5.559e-44 x  - 5.747e-43 x  - 4.954e-42 x
#               51             50             49             48
#  - 3.337e-41 x  - 1.191e-40 x  + 1.088e-39 x  + 3.074e-38 x
#               47            46             45             44
#  + 4.388e-37 x  + 4.78e-36 x  + 4.175e-35 x  + 2.709e-34 x
#               43             42             41             40
#  + 7.034e-34 x  - 1.385e-32 x  - 3.068e-31 x  - 3.937e-30 x
#               39             38             37             36
#  - 3.769e-29 x  - 2.607e-28 x  - 7.661e-28 x  + 1.228e-26 x
#               35             34             33             32
#  + 2.775e-25 x  + 3.379e-24 x  + 2.832e-23 x  + 1.308e-22 x
#               31             30             29             28
#  - 6.443e-22 x  - 2.268e-20 x  - 2.884e-19 x  - 2.202e-18 x
#               27             26             25             24
#  - 5.114e-18 x  + 1.368e-16 x  + 2.435e-15 x  + 2.051e-14 x
#               23             22             21             20
#  + 4.098e-14 x  - 1.432e-12 x  - 2.146e-11 x  - 1.125e-10 x
#               19             18            17             16
#  + 8.165e-10 x  + 1.874e-08 x  + 9.03e-08 x  - 1.051e-06 x
#               15             14            13            12          11
#  - 1.497e-05 x  + 2.699e-05 x  + 0.001415 x  - 0.002185 x  - 0.1131 x
#            10         9         8         7         6         5       4
#  + 0.9221 x  - 2.492 x - 3.965 x + 50.39 x - 173.2 x + 332.7 x - 392 x
#           3         2
#  + 282.7 x - 118.3 x + 25.54 x + 2.945
# C:\Users\PC\AppData\Local\Temp\ipykernel_21248\1790378693.py:34: RankWarning: Polyfit may be poorly conditioned
#   coef_interp = np.polyfit(x_filtrado, y_filtrado, grado)
